# %%
import pandas as pd
from lxml import etree
from xml.etree import ElementTree as ET
import time

# %%
with open('D:/data/hmdb_metabolites/hmdb_metabolites.xml','r',encoding='utf-8',errors='ignore') as f:
    for i in range(5000):
        byt=f.readline()
#         print(byt)
#         if(byt=='<metabolite>\n'):
        print(byt)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <hmdb xmlns="http://www.hmdb.ca">
#
# <metabolite>
#
#   <version>5.0</version>
#
#   <creation_date>2005-11-16 15:48:42 UTC</creation_date>
#
#   <update_date>2021-10-13 17:34:04 UTC</update_date>
#
#   <accession>HMDB0000001</accession>
#
#   <status>quantified</status>
#
#   <secondary_accessions>
#
#     <accession>HMDB00001</accession>
#
#     <accession>HMDB0004935</accession>
#
#     <accession>HMDB0006703</accession>
#
#     <accession>HMDB0006704</accession>
#
#     <accession>HMDB04935</accession>
#
#     <accession>HMDB06703</accession>
#
#     <accession>HMDB06704</accession>
#
#   </secondary_accessions>
#
#   <name>1-Methylhistidine</name>
#
# ...

# %%
with open('D:/data/hmdb_proteins/hmdb_proteins.xml','r',encoding='utf-8',errors='ignore') as f:
    for i in range(100):
        byt=f.readline()
        print(byt)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
#
# <hmdb xmlns="http://www.hmdb.ca">
#
# <protein>
#
#   <version>5.0</version>
#
#   <creation_date>2013-01-16 01:48:37 UTC</creation_date>
#
#   <update_date>2017-12-08 07:09:13 UTC</update_date>
#
#   <accession>HMDBP00001</accession>
#
#   <name>5'-nucleotidase</name>
#
#   <secondary_accessions>
#
#     <accession>5229</accession>
#
#   </secondary_accessions>
#
#   <protein_type>Unknown</protein_type>
#
#   <synonyms>
#
#     <synonym>5'-NT</synonym>
#
#     <synonym>CD73 antigen</synonym>
#
#     <synonym>Ecto-5'-nucleotidase</synonym>
#
#   </synonyms>
#
#   <gene_name>NT5E</gene_name>
#
#   <general_function>Involved in hydrolase activity</general_function>
#
#   <specific_function>Hydrolyzes extracellular nucleotides into membrane permeable nucleosides.
#
# </specific_function>
#
#   <pathways>
#
#     <pathway>
#
#       <name>Nicotinate and nicotinamide metabolism</name>
#
#       <smpdb_id/>
#
# ...

# %%
from xml.etree import ElementTree as ET

# %%
with open('D:/data/hmdb_metabolites/meta1.xml','rb+') as xml:
        print(xml)
        tree=ET.parse(xml)
        print(tree)
        root = tree.getroot()
        print(root)
        print(root.tag, ":", root.attrib)
        
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                print(child2.tag, ":", child2.attrib)
            print('-----------------------------------------------')
        
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag != '{http://www.hmdb.ca}normal_concentrations'):
                    print('ok')
                    print(child2.tag, ":", child2.attrib)
                    child1.remove(child2)
                    
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                print(child2.tag, ":", child2.attrib)
                
#         xml.seek(0)
#         xml.truncate()
#         tree.write(xml)
                
#         for child1 in root:
#             # 第二层节点的标签名和属性
#             print('-----------------------------------------------')
#             print(child1.tag, ":", child1.attrib)
#             for child2 in child1:
#                 # 第三层节点的变迁名称和属性
#                 print(child2.tag, ":", child2.attrib)
# Out:
# <_io.BufferedRandom name='D:/data/hmdb_metabolites/meta1.xml'>
# ...
# <Element '{http://www.hmdb.ca}hmdb' at 0x0000028082576458>
# {http://www.hmdb.ca}hmdb : {}
# {http://www.hmdb.ca}metabolite : {}
# {http://www.hmdb.ca}version : {}
# {http://www.hmdb.ca}creation_date : {}
# {http://www.hmdb.ca}update_date : {}
# {http://www.hmdb.ca}accession : {}
# {http://www.hmdb.ca}status : {}
# {http://www.hmdb.ca}secondary_accessions : {}
# {http://www.hmdb.ca}name : {}
# {http://www.hmdb.ca}description : {}
# {http://www.hmdb.ca}synonyms : {}
# {http://www.hmdb.ca}chemical_formula : {}
# {http://www.hmdb.ca}average_molecular_weight : {}
# {http://www.hmdb.ca}monisotopic_molecular_weight : {}
# {http://www.hmdb.ca}iupac_name : {}
# {http://www.hmdb.ca}traditional_iupac : {}
# {http://www.hmdb.ca}cas_registry_number : {}
# {http://www.hmdb.ca}smiles : {}
# {http://www.hmdb.ca}inchi : {}
# {http://www.hmdb.ca}inchikey : {}
# {http://www.hmdb.ca}taxonomy : {}
# {http://www.hmdb.ca}ontology : {}
# ...

# %%
print("haha")
p=per.findall('vesion')
        print(p)
ch=child.getchildren()[1]
            print(ch.tag)
# Out:
# haha

# %%
with open('D:/data/hmdb_metabolites/meta1.xml','rb+') as xml:
        print(xml)
        per=ET.parse(xml)
        print(per)
        root = per.getroot()
        print(root)
        print(root.tag, ":", root.attrib)
        
#         for child1 in root:
#             # 第二层节点的标签名和属性
#             print(child1.tag, ":", child1.attrib)
#             for child2 in child1:
#                 # 第三层节点的变迁名称和属性
#                 print(child2.tag, ":", child2.attrib)
#             print('-----------------------------------------------')
        
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag!='{http://www.hmdb.ca}name'):
                    print('ok')
                    child1.remove(child2)
                    continue
                print("hhhhh")
                print(child2.tag, ":", child2.attrib)
                
                
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag!='{http://www.hmdb.ca}name'):
                    print('ok')
                    child1.remove(child2)
                    continue
                print("hhhhh")
                print(child2.tag, ":", child2.attrib)
                
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag!='{http://www.hmdb.ca}name'):
                    print('ok')
                    child1.remove(child2)
                    continue
                print("hhhhh")
                print(child2.tag, ":", child2.attrib)
                
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag!='{http://www.hmdb.ca}name'):
                    print('ok')
                    child1.remove(child2)
                    continue
                print("hhhhh")
                print(child2.tag, ":", child2.attrib)
        
        for child1 in root:
            # 第二层节点的标签名和属性
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                #if(child2.tag!='{http://www.hmdb.ca}normal_concentrations'and child2.tag!='{http://www.hmdb.ca}abnormal_concentrations'and child2.tag!='{http://www.hmdb.ca}diseases'and child2.tag!='{http://www.hmdb.ca}protein_associations'):
                if(child2.tag!='{http://www.hmdb.ca}name'):
                    print('ok')
                    child1.remove(child2)
                    continue
                print("hhhhh")
                print(child2.tag, ":", child2.attrib)
        
        for child1 in root:
            # 第二层节点的标签名和属性
            print('-----------------------------------------------')
            print(child1.tag, ":", child1.attrib)
            for child2 in child1:
                # 第三层节点的变迁名称和属性
                print(child2.tag, ":", child2.attrib)
# Out:
# <_io.BufferedRandom name='D:/data/hmdb_metabolites/meta1.xml'>
# ...
# <Element '{http://www.hmdb.ca}hmdb' at 0x00000251A30C5E08>
# {http://www.hmdb.ca}hmdb : {}
# {http://www.hmdb.ca}metabolite : {}
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# ok
# {http://www.hmdb.ca}metabolite : {}
# ok
# ok
# ok
# ok
# ok
# ok
# {http://www.hmdb.ca}metabolite : {}
# hhhhh
# {http://www.hmdb.ca}name : {}
# ok
# ok
# {http://www.hmdb.ca}metabolite : {}
# hhhhh
# {http://www.hmdb.ca}name : {}
# ok
# {http://www.hmdb.ca}metabolite : {}
# hhhhh
# {http://www.hmdb.ca}name : {}
# ok
# -----------------------------------------------
# {http://www.hmdb.ca}metabolite : {}
# {http://www.hmdb.ca}name : {}

# %%
# Data = {}
# DataFrame = pd.DataFrame(Data,columns=["Mid","N.C"])
# DataFrame.to_csv("D:/data/hmdb_metabolites/data.csv", index=False, sep=',') 

with open('D:/data/hmdb_metabolites/meta1.xml','rb+') as xml:
    print(xml)
    per=ET.parse(xml)
    print(per)
    root = per.getroot()
    print(root)
    print(root.tag, ":", root.attrib)

#         for child1 in root:
#             # 第二层节点的标签名和属性
#             print(child1.tag, ":", child1.attrib)
#             for child2 in child1:
#                 # 第三层节点的变迁名称和属性
#                 print(child2.tag, ":", child2.attrib)
#             print('-----------------------------------------------')

    for child1 in root:
        dp={}
        for i in range(46):
#             print(len(child1.getchildren()))    
            child=child1.getchildren()[i]
            if(child.tag == '{http://www.hmdb.ca}accession'):
#                 print(i)
                dp['mid']=child.text
                print(child.text)
                mid=child.text

            if(child.tag == '{http://www.hmdb.ca}normal_concentrations'):
                print(i)
                print(child.tag,'  ',child.text)
                c=child.getchildren()[0]
                nc=c.getchildren()[1]
                print('ok')
                print(nc.tag,nc.text)
                c=child.getchildren()[1]
                nc=c.getchildren()[1]
                print('okk')
                print(nc.tag,nc.text)
                c=child.getchildren()[2]
                nc=c.getchildren()[1]
                print('okk')
                print(nc.tag,nc.text)
                NC=nc.text
                dp['N.C']=NC
        
        print(dp)
        df=pd.DataFrame([dp])
        print(df)
#         df.to_csv('D:/data/hmdb_metabolites/data.csv', mode='a', index=False,header=False)          
                    
#                         child1.remove(child)
# Out:
# <_io.BufferedRandom name='D:/data/hmdb_metabolites/meta1.xml'>
# ...
# <Element '{http://www.hmdb.ca}hmdb' at 0x000001E3642861D8>
# {http://www.hmdb.ca}hmdb : {}
# HMDB0000001
# 25
# {http://www.hmdb.ca}normal_concentrations
#
#
# ok
# {http://www.hmdb.ca}concentration_value None
# okk
# {http://www.hmdb.ca}concentration_value 7.7 +/- 1.9
# okk
# {http://www.hmdb.ca}concentration_value 14.4 +/- 2.3
# {'mid': 'HMDB0000001', 'N.C': '14.4 +/- 2.3'}
#            mid           N.C
# 0  HMDB0000001  14.4 +/- 2.3
# F:\Anaconda3\envs\python38\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# F:\Anaconda3\envs\python38\lib\site-packages\ipykernel_launcher.py:35: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# ...

# %%
Data = {}
DataFrame = pd.DataFrame(Data,columns=["Mid","N.C"])
DataFrame.to_csv("D:/data/hmdb_metabolites/data.csv", index=False, sep=',')

# %%
Data = {}
DataFrame = pd.DataFrame(Data,columns=["Mid","Kegg_ID"])
DataFrame.to_csv("D:/data/hmdb_metabolites/data_keggID.csv", index=False, sep=',')

# %%
with open('D:/data/hmdb_metabolites/meta1.xml','rb+') as xml:
#     print(xml)
    per=ET.parse(xml)
#     print(per)
    root = per.getroot()
#     print(root)
#     print(root.tag, ":", root.attrib)

#         for child1 in root:
#             # 第二层节点的标签名和属性
#             print(child1.tag, ":", child1.attrib)
#             for child2 in child1:
#                 # 第三层节点的变迁名称和属性
#                 print(child2.tag, ":", child2.attrib)
#             print('-----------------------------------------------')

    for child1 in root:
        dp={}
        for i in range(len(child1.getchildren())):
            child=child1.getchildren()[i]
            print(child.tag)
            if(child.tag == '{http://www.hmdb.ca}accession'):
#                 print(i)
                dp['mid']=child.text
#                 print(child.text)
                mid=child.text
            if(child.tag == '{http://www.hmdb.ca}kegg_id'):
#                 print(child.text)
                kegg=child.text
                dp['kegg_id']=kegg
        print(dp)
        df=pd.DataFrame([dp])
        print(df)
        df.to_csv('D:/data/hmdb_metabolites/data_keggID.csv', mode='a', index=False,header=False)
#     xml.seek(0)
#     xml.truncate()
#     per.write(xml)
# Out:
# {http://www.hmdb.ca}version
# {http://www.hmdb.ca}creation_date
# {http://www.hmdb.ca}update_date
# {http://www.hmdb.ca}accession
# {http://www.hmdb.ca}status
# {http://www.hmdb.ca}secondary_accessions
# {http://www.hmdb.ca}name
# {http://www.hmdb.ca}description
# {http://www.hmdb.ca}synonyms
# {http://www.hmdb.ca}chemical_formula
# {http://www.hmdb.ca}average_molecular_weight
# {http://www.hmdb.ca}monisotopic_molecular_weight
# {http://www.hmdb.ca}iupac_name
# {http://www.hmdb.ca}traditional_iupac
# {http://www.hmdb.ca}cas_registry_number
# {http://www.hmdb.ca}smiles
# {http://www.hmdb.ca}inchi
# {http://www.hmdb.ca}inchikey
# {http://www.hmdb.ca}taxonomy
# {http://www.hmdb.ca}ontology
# {http://www.hmdb.ca}state
# {http://www.hmdb.ca}experimental_properties
# {http://www.hmdb.ca}predicted_properties
# {http://www.hmdb.ca}spectra
# {http://www.hmdb.ca}biological_properties
# {http://www.hmdb.ca}normal_concentrations
# {http://www.hmdb.ca}abnormal_concentrations
# ...

# %%
Data = {}
DataFrame = pd.DataFrame(Data,columns=["Mid","Mname","Kegg_ID"])
DataFrame.to_csv("D:/data/hmdb_metabolites/data_keggID.csv", index=False, sep=',')

# %%
# 从原始数据库代谢物xml文件中提取数据脚本框架
import warnings
warnings.filterwarnings("ignore")  #重要 不然21万多条数据所生成的warning会直接把jupyter脚本文件挤爆
import pandas as pd
from lxml import etree
from xml.etree import ElementTree as ET
import time

# 动态写入存储
Data = {}
DataFrame = pd.DataFrame(Data,columns=["Mid","Mname","Kegg_ID"])
DataFrame.to_csv("D:/data/hmdb_metabolites/data_keggID.csv", index=False, sep=',') 

with open('D:/data/hmdb_metabolites/hmdb_metabolites.xml','r',encoding='utf-8',errors='ignore') as f:
# with open('D:/data/hmdb_metabolites/meta1.xml','r',encoding='utf-8',errors='ignore') as f:

#     for i in range(6):
    while True:
        byt=f.readline()
#         print(byt)
        
        if(byt=='<metabolite>\n'):
#             print(byt)
#             with open("D:/data/hmdb_metabolites/test.txt","w") as f2:
            with open('D:/data/hmdb_metabolites/test.xml','w',encoding='utf-8',errors='ignore') as f2:
                f2.write('<?xml version="1.0" encoding="UTF-8"?>\n<hmdb xmlns="http://www.hmdb.ca">\n<metabolite>\n')
                while(byt!='</metabolite>\n'):
                    byt=f.readline()
                    f2.write(byt)
                    if(byt=='</hmdb>\n'):
                        break
                f2.write('</hmdb>')
            with open('D:/data/hmdb_metabolites/test.xml','rb+') as xml:
                per=ET.parse(xml)
                root = per.getroot()

                for child1 in root:
                    dp={}
                    for i in range(len(child1.getchildren())):
                        child=child1.getchildren()[i]
            #             print(child.tag)
                        if(child.tag == '{http://www.hmdb.ca}accession'):
            #                 print(i)
                            dp['mid']=child.text
            #                 print(child.text)
                            mid=child.text
                        if(child.tag == '{http://www.hmdb.ca}name'):
            #                 print(i)
                            dp['mname']=child.text
            #                 print(child.text)
                            mid=child.text
                        if(child.tag == '{http://www.hmdb.ca}kegg_id'):
            #                 print(child.text)
                            kegg=child.text
                            dp['kegg_id']=kegg
#                     print(dp)
                    df=pd.DataFrame([dp])
#                     print(df)
                    df.to_csv('D:/data/hmdb_metabolites/data_keggID.csv', mode='a', index=False,header=False)
        if(byt=='</hmdb>\n'):
            break
        if(byt=='</hmdb>'):
            break
